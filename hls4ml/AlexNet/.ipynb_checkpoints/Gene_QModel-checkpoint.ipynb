# %%
import tensorflow as tf
import keras
import time
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator

import qkeras
from qkeras import QActivation
from qkeras import QDense, QConv2DBatchnorm

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l1
from tensorflow.keras.models import Model

from callbacks import all_callbacks
# Out:
# 2023-06-29 02:06:32.844297: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

cifar10_classes=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, MaxPooling2D, Flatten, Activation
from qkeras import QActivation, QDense, QConv2D
from qkeras.quantizers import quantized_bits, quantized_relu
from tensorflow.keras.regularizers import l1, l2

# 输入层
input_layer = Input(shape=(32, 32, 3))

# 第一层卷积层
x = QConv2D(
    64,
    kernel_size=(3, 3),
    strides=(4, 4),
    padding='valid',
    name='conv1',
    kernel_quantizer=quantized_bits(6, 0, alpha=1),
    bias_quantizer=quantized_bits(6, 0, alpha=1),
    kernel_initializer='lecun_uniform',
    kernel_regularizer=l2(0.0001)
)(input_layer)
x = QActivation(activation=quantized_relu(6), name='relu1')(x)
x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='valid', name='pool1')(x)

# 第二层卷积层
x = QConv2D(
    4,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding='same',
    name='conv2',
    kernel_quantizer=quantized_bits(6, 0, alpha=1),
    bias_quantizer=quantized_bits(6, 0, alpha=1),
    kernel_initializer='lecun_uniform',
    kernel_regularizer=l2(0.0001)
)(x)
x = QActivation(activation=quantized_relu(6), name='relu2')(x)
x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same', name='pool2')(x)

# 第三层卷积层
x = QConv2D(
    64,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding='same',
    name='conv3',
    kernel_quantizer=quantized_bits(6, 0, alpha=1),
    bias_quantizer=quantized_bits(6, 0, alpha=1),
    kernel_initializer='lecun_uniform',
    kernel_regularizer=l2(0.0001)
)(x)
x = QActivation(activation=quantized_relu(6), name='relu3')(x)

# 第四层卷积层
x = QConv2D(
    8,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding='same',
    name='conv4',
    kernel_quantizer=quantized_bits(6, 0, alpha=1),
    bias_quantizer=quantized_bits(6, 0, alpha=1),
    kernel_initializer='lecun_uniform',
    kernel_regularizer=l2(0.0001)
)(x)
x = QActivation(activation=quantized_relu(6), name='relu4')(x)

# 第五层卷积层
x = QConv2D(
    32,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding='same',
    name='conv5',
    kernel_quantizer=quantized_bits(6, 0, alpha=1),
    bias_quantizer=quantized_bits(6, 0, alpha=1),
    kernel_initializer='lecun_uniform',
    kernel_regularizer=l1(0.0001)
)(x)
x = QActivation(activation=quantized_relu(6), name='relu5')(x)
x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same', name='pool5')(x)

# 全连接层
x = Flatten()(x)
x = QDense(
    64,
    name='fc1',
    kernel_quantizer=quantized_bits(6, 0, alpha=1),
    bias_quantizer=quantized_bits(6, 0, alpha=1),
    kernel_initializer='lecun_uniform',
    kernel_regularizer=l2(0.0001)
)(x)
x = QActivation(activation=quantized_relu(6), name='relu6')(x)

x = QDense(
    32,
    name='fc2',
    kernel_quantizer=quantized_bits(6, 0, alpha=1),
    bias_quantizer=quantized_bits(6, 0, alpha=1),
    kernel_initializer='lecun_uniform',
    kernel_regularizer=l2(0.0001)
)(x)
x = QActivation(activation=quantized_relu(6), name='relu7')(x)

x = QDense(
    10,
    name='output',
    kernel_quantizer=quantized_bits(6, 0, alpha=1),
    bias_quantizer=quantized_bits(6, 0, alpha=1),
    kernel_initializer='lecun_uniform',
    kernel_regularizer=l1(0.0001)
)(x)
output_layer = Activation(activation='softmax', name='softmax')(x)

# 构建模型
model = Model(inputs=input_layer, outputs=output_layer)

# 打印模型概况
model.summary()
# Out:
# 2023-06-29 02:06:34.746816: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-06-29 02:06:34.807294: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 02:06:34.807648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.74GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-06-29 02:06:34.807670: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-06-29 02:06:34.809974: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-06-29 02:06:34.810012: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-06-29 02:06:34.811187: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-06-29 02:06:34.811369: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-06-29 02:06:34.813710: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-06-29 02:06:34.814280: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-06-29 02:06:34.814373: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-06-29 02:06:34.814439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 02:06:34.814799: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 02:06:34.815107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-06-29 02:06:34.815489: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 02:06:34.816804: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 02:06:34.817127: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.74GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-06-29 02:06:34.817174: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 02:06:34.817507: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 02:06:34.817807: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-06-29 02:06:34.817832: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-06-29 02:06:35.244323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-06-29 02:06:35.244347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-06-29 02:06:35.244354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-06-29 02:06:35.244471: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 02:06:35.244783: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 02:06:35.245075: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-29 02:06:35.245356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9292 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv1 (QConv2D)              (None, 8, 8, 64)          1792
# _________________________________________________________________
# relu1 (QActivation)          (None, 8, 8, 64)          0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2 (QConv2D)              (None, 3, 3, 4)           2308
# _________________________________________________________________
# relu2 (QActivation)          (None, 3, 3, 4)           0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 2, 2, 4)           0
# _________________________________________________________________
# conv3 (QConv2D)              (None, 2, 2, 64)          2368
# _________________________________________________________________
# relu3 (QActivation)          (None, 2, 2, 64)          0
# _________________________________________________________________
# conv4 (QConv2D)              (None, 2, 2, 8)           4616
# _________________________________________________________________
# relu4 (QActivation)          (None, 2, 2, 8)           0
# _________________________________________________________________
# conv5 (QConv2D)              (None, 2, 2, 32)          2336
# _________________________________________________________________
# relu5 (QActivation)          (None, 2, 2, 32)          0
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# fc1 (QDense)                 (None, 64)                2112
# _________________________________________________________________
# relu6 (QActivation)          (None, 64)                0
# _________________________________________________________________
# fc2 (QDense)                 (None, 32)                2080
# _________________________________________________________________
# relu7 (QActivation)          (None, 32)                0
# _________________________________________________________________
# output (QDense)              (None, 10)                330
# _________________________________________________________________
# softmax (Activation)         (None, 10)                0
# =================================================================
# Total params: 17,942
# Trainable params: 17,942
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning

pruning_params = {"pruning_schedule": pruning_schedule.ConstantSparsity(0.75, begin_step=2000, frequency=100)}
model = prune.prune_low_magnitude(model, **pruning_params)

# %%
train = True
if train:
    adam = Adam(lr=0.001)
    model.compile(optimizer=adam, loss=['categorical_crossentropy'], metrics=['accuracy'])
    
    callbacks = all_callbacks(
        stop_patience=1000,
        lr_factor=0.5,
        lr_patience=10,
        lr_epsilon=0.000001,
        lr_cooldown=2,
        lr_minimum=0.0000001,
        outputDir='AlexNet_Weights/Qkeras',
    )
    callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
    
    model.fit(
        x_train,
        y_train,
        batch_size=1024,
        epochs=5000,
        validation_split=0.25,
        shuffle=True,
        callbacks=callbacks.callbacks,
    )
    # Save the model again but with the pruning 'stripped' to use the regular layer types
    model = strip_pruning(model)
    model.save('AlexNet_Weights/AlexNet_check_best_model.h5')
else:
    from tensorflow.keras.models import load_model
    from qkeras.utils import _add_supported_quantized_objects

    co = {}
    _add_supported_quantized_objects(co)
    model = load_model('AlexNet_Weights/AlexNet_check_best_model.h5', custom_objects=co)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /home/lab-shi/anaconda3/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 2023-06-29 02:06:38.359646: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2023-06-29 02:06:38.359665: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# 2023-06-29 02:06:38.359696: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1611] Profiler found 1 GPUs
# 2023-06-29 02:06:38.360097: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64::/usr/local/hdf5/lib
# 2023-06-29 02:06:38.360175: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so'; dlerror: libcupti.so: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64::/usr/local/hdf5/lib
# 2023-06-29 02:06:38.360187: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1661] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI could not be loaded or symbol could not be found.
# 2023-06-29 02:06:38.360210: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.
# 2023-06-29 02:06:38.360225: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1752] function cupti_interface_->Finalize()failed with error CUPTI could not be loaded or symbol could not be found.
# 2023-06-29 02:06:39.247926: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-06-29 02:06:39.267168: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3600000000 Hz
# Epoch 1/5000
# WARNING:tensorflow:From /home/lab-shi/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 2023-06-29 02:06:43.394360: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:808] layout failed: Invalid argument: Size of values 0 does not match size of permutation 4 @ fanin shape ingradient_tape/model/prune_low_magnitude_relu5/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-06-29 02:06:43.958253: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-06-29 02:06:44.404888: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8101
# 2023-06-29 02:06:44.935584: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-06-29 02:06:45.338291: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
#  3/37 [=>............................] - ETA: 3s - loss: 2.3536 - accuracy: 0.1104WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0110s vs `on_train_batch_end` time: 0.0348s). Check your callbacks.
# 13/37 [=========>....................] - ETA: 0s - loss: 2.3483 - accuracy: 0.1061
# 2023-06-29 02:06:45.771142: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2023-06-29 02:06:45.771162: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# 2023-06-29 02:06:45.771235: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1661] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI could not be loaded or symbol could not be found.
# 2023-06-29 02:06:45.786603: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2023-06-29 02:06:45.786678: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1752] function cupti_interface_->Finalize()failed with error CUPTI could not be loaded or symbol could not be found.
# 2023-06-29 02:06:45.792161: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2023-06-29 02:06:45.795209: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.
# 2023-06-29 02:06:45.799242: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45
# 2023-06-29 02:06:45.800511: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45/labshi-MP-i1640.trace.json.gz
# 2023-06-29 02:06:45.824786: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45
# 2023-06-29 02:06:45.827418: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45/labshi-MP-i1640.memory_profile.json.gz
# 2023-06-29 02:06:45.827667: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45Dumped tool data for xplane.pb to AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45/labshi-MP-i1640.xplane.pb
# Dumped tool data for overview_page.pb to AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45/labshi-MP-i1640.overview_page.pb
# Dumped tool data for input_pipeline.pb to AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45/labshi-MP-i1640.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45/labshi-MP-i1640.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to AlexNet_Weights/Qkeras/logs/train/plugins/profile/2023_06_29_02_06_45/labshi-MP-i1640.kernel_stats.pb
# 37/37 [==============================] - 8s 50ms/step - loss: 2.3102 - accuracy: 0.1260 - val_loss: 2.2168 - val_accuracy: 0.1669
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00001: val_loss improved from inf to 2.21681, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 2.21681, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00001: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 2/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 2.1293 - accuracy: 0.1791 - val_loss: 2.0648 - val_accuracy: 0.1946
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00002: val_loss improved from 2.21681 to 2.06479, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 2.21681 to 2.06479, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00002: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 3/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 2.0373 - accuracy: 0.2093 - val_loss: 2.0063 - val_accuracy: 0.2273
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00003: val_loss improved from 2.06479 to 2.00630, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 2.06479 to 2.00630, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00003: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 4/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.9929 - accuracy: 0.2299 - val_loss: 1.9939 - val_accuracy: 0.2243
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00004: val_loss improved from 2.00630 to 1.99385, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 2.00630 to 1.99385, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00004: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 5/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.9628 - accuracy: 0.2394 - val_loss: 1.9646 - val_accuracy: 0.2381
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00005: val_loss improved from 1.99385 to 1.96458, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00005: val_loss improved from 1.99385 to 1.96458, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00005: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00005: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 6/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.9271 - accuracy: 0.2555 - val_loss: 1.8967 - val_accuracy: 0.2658
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00006: val_loss improved from 1.96458 to 1.89673, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00006: val_loss improved from 1.96458 to 1.89673, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00006: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00006: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 7/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.8926 - accuracy: 0.2698 - val_loss: 1.8642 - val_accuracy: 0.2774
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00007: val_loss improved from 1.89673 to 1.86424, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00007: val_loss improved from 1.89673 to 1.86424, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00007: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00007: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 8/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.8520 - accuracy: 0.2802 - val_loss: 1.8385 - val_accuracy: 0.2822
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00008: val_loss improved from 1.86424 to 1.83853, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00008: val_loss improved from 1.86424 to 1.83853, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00008: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00008: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 9/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.8344 - accuracy: 0.2857 - val_loss: 1.8210 - val_accuracy: 0.2910
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00009: val_loss improved from 1.83853 to 1.82104, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00009: val_loss improved from 1.83853 to 1.82104, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00009: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00009: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 10/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.8012 - accuracy: 0.3009 - val_loss: 1.8025 - val_accuracy: 0.2978
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00010: val_loss improved from 1.82104 to 1.80255, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00010: val_loss improved from 1.82104 to 1.80255, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00010: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00010: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# Epoch 11/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.7928 - accuracy: 0.3033 - val_loss: 1.7966 - val_accuracy: 0.3018
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00011: val_loss improved from 1.80255 to 1.79664, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00011: val_loss improved from 1.80255 to 1.79664, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00011: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00011: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 12/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.7686 - accuracy: 0.3185 - val_loss: 1.7654 - val_accuracy: 0.3199
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00012: val_loss improved from 1.79664 to 1.76536, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00012: val_loss improved from 1.79664 to 1.76536, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00012: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00012: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 13/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.7502 - accuracy: 0.3251 - val_loss: 1.7905 - val_accuracy: 0.3078
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00013: val_loss did not improve from 1.76536
#
# Epoch 00013: val_loss did not improve from 1.76536
#
# Epoch 00013: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
# Epoch 00013: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 14/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.7530 - accuracy: 0.3264 - val_loss: 1.7579 - val_accuracy: 0.3222
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00014: val_loss improved from 1.76536 to 1.75790, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00014: val_loss improved from 1.76536 to 1.75790, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00014: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00014: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 15/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.7215 - accuracy: 0.3359 - val_loss: 1.7379 - val_accuracy: 0.3347
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00015: val_loss improved from 1.75790 to 1.73790, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00015: val_loss improved from 1.75790 to 1.73790, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00015: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00015: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 16/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.7156 - accuracy: 0.3410 - val_loss: 1.7199 - val_accuracy: 0.3413
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00016: val_loss improved from 1.73790 to 1.71989, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00016: val_loss improved from 1.73790 to 1.71989, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00016: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00016: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 17/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.7049 - accuracy: 0.3438 - val_loss: 1.7323 - val_accuracy: 0.3374
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00017: val_loss did not improve from 1.71989
#
# Epoch 00017: val_loss did not improve from 1.71989
#
# Epoch 00017: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00017: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 18/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6943 - accuracy: 0.3493 - val_loss: 1.7004 - val_accuracy: 0.3455
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00018: val_loss improved from 1.71989 to 1.70036, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 1.71989 to 1.70036, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00018: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 19/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6851 - accuracy: 0.3533 - val_loss: 1.6934 - val_accuracy: 0.3500
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00019: val_loss improved from 1.70036 to 1.69345, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00019: val_loss improved from 1.70036 to 1.69345, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00019: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00019: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 20/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6936 - accuracy: 0.3514 - val_loss: 1.7090 - val_accuracy: 0.3461
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00020: val_loss did not improve from 1.69345
#
# Epoch 00020: val_loss did not improve from 1.69345
#
# Epoch 00020: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00020: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# Epoch 21/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6749 - accuracy: 0.3579 - val_loss: 1.7132 - val_accuracy: 0.3418
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00021: val_loss did not improve from 1.69345
#
# Epoch 00021: val_loss did not improve from 1.69345
#
# Epoch 00021: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00021: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 22/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.7040 - accuracy: 0.3526 - val_loss: 1.6921 - val_accuracy: 0.3594
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00022: val_loss improved from 1.69345 to 1.69207, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00022: val_loss improved from 1.69345 to 1.69207, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00022: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00022: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 23/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6779 - accuracy: 0.3585 - val_loss: 1.6825 - val_accuracy: 0.3589
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00023: val_loss improved from 1.69207 to 1.68249, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 1.69207 to 1.68249, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00023: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 24/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6599 - accuracy: 0.3671 - val_loss: 1.7371 - val_accuracy: 0.3594
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00024: val_loss did not improve from 1.68249
#
# Epoch 00024: val_loss did not improve from 1.68249
#
# Epoch 00024: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00024: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 25/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6600 - accuracy: 0.3695 - val_loss: 1.6721 - val_accuracy: 0.3730
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00025: val_loss improved from 1.68249 to 1.67210, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00025: val_loss improved from 1.68249 to 1.67210, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00025: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00025: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 26/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6668 - accuracy: 0.3667 - val_loss: 1.6669 - val_accuracy: 0.3782
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00026: val_loss improved from 1.67210 to 1.66695, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00026: val_loss improved from 1.67210 to 1.66695, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00026: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00026: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 27/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6497 - accuracy: 0.3756 - val_loss: 1.6498 - val_accuracy: 0.3818
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00027: val_loss improved from 1.66695 to 1.64984, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00027: val_loss improved from 1.66695 to 1.64984, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00027: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00027: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 28/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6355 - accuracy: 0.3833 - val_loss: 1.6677 - val_accuracy: 0.3746
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00028: val_loss did not improve from 1.64984
#
# Epoch 00028: val_loss did not improve from 1.64984
#
# Epoch 00028: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00028: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 29/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6379 - accuracy: 0.3815 - val_loss: 1.6658 - val_accuracy: 0.3702
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00029: val_loss did not improve from 1.64984
#
# Epoch 00029: val_loss did not improve from 1.64984
#
# Epoch 00029: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00029: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 30/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6190 - accuracy: 0.3910 - val_loss: 1.6385 - val_accuracy: 0.3882
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00030: val_loss improved from 1.64984 to 1.63853, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00030: val_loss improved from 1.64984 to 1.63853, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00030: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00030: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# Epoch 31/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6236 - accuracy: 0.3900 - val_loss: 1.6497 - val_accuracy: 0.3810
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00031: val_loss did not improve from 1.63853
#
# Epoch 00031: val_loss did not improve from 1.63853
#
# Epoch 00031: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00031: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 32/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6316 - accuracy: 0.3882 - val_loss: 1.6719 - val_accuracy: 0.3730
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00032: val_loss did not improve from 1.63853
#
# Epoch 00032: val_loss did not improve from 1.63853
#
# Epoch 00032: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00032: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 33/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6247 - accuracy: 0.3905 - val_loss: 1.6263 - val_accuracy: 0.3947
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00033: val_loss improved from 1.63853 to 1.62631, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00033: val_loss improved from 1.63853 to 1.62631, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00033: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00033: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 34/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6260 - accuracy: 0.3906 - val_loss: 1.6350 - val_accuracy: 0.3906
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00034: val_loss did not improve from 1.62631
#
# Epoch 00034: val_loss did not improve from 1.62631
#
# Epoch 00034: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00034: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 35/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6242 - accuracy: 0.3923 - val_loss: 1.7215 - val_accuracy: 0.3760
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00035: val_loss did not improve from 1.62631
#
# Epoch 00035: val_loss did not improve from 1.62631
#
# Epoch 00035: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00035: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 36/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6183 - accuracy: 0.3938 - val_loss: 1.6478 - val_accuracy: 0.3869
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00036: val_loss did not improve from 1.62631
#
# Epoch 00036: val_loss did not improve from 1.62631
#
# Epoch 00036: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00036: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 37/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6073 - accuracy: 0.3987 - val_loss: 1.6268 - val_accuracy: 0.4043
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00037: val_loss did not improve from 1.62631
#
# Epoch 00037: val_loss did not improve from 1.62631
#
# Epoch 00037: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00037: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 38/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6158 - accuracy: 0.3942 - val_loss: 1.6318 - val_accuracy: 0.3979
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00038: val_loss did not improve from 1.62631
#
# Epoch 00038: val_loss did not improve from 1.62631
#
# Epoch 00038: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00038: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 39/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6253 - accuracy: 0.3939 - val_loss: 1.7269 - val_accuracy: 0.3771
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00039: val_loss did not improve from 1.62631
#
# Epoch 00039: val_loss did not improve from 1.62631
#
# Epoch 00039: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00039: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 40/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6032 - accuracy: 0.3994 - val_loss: 1.6149 - val_accuracy: 0.4016
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00040: val_loss improved from 1.62631 to 1.61491, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00040: val_loss improved from 1.62631 to 1.61491, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00040: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00040: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# Epoch 00040: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# Epoch 41/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6083 - accuracy: 0.4000 - val_loss: 1.6190 - val_accuracy: 0.4009
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00041: val_loss did not improve from 1.61491
#
# Epoch 00041: val_loss did not improve from 1.61491
#
# Epoch 00041: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00041: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 42/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6092 - accuracy: 0.4016 - val_loss: 1.6288 - val_accuracy: 0.3982
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00042: val_loss did not improve from 1.61491
#
# Epoch 00042: val_loss did not improve from 1.61491
#
# Epoch 00042: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00042: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 43/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6006 - accuracy: 0.4053 - val_loss: 1.6670 - val_accuracy: 0.3898
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00043: val_loss did not improve from 1.61491
#
# Epoch 00043: val_loss did not improve from 1.61491
#
# Epoch 00043: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00043: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 44/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6046 - accuracy: 0.4050 - val_loss: 1.7186 - val_accuracy: 0.3775
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00044: val_loss did not improve from 1.61491
#
# Epoch 00044: val_loss did not improve from 1.61491
#
# Epoch 00044: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00044: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 45/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6124 - accuracy: 0.4032 - val_loss: 1.6269 - val_accuracy: 0.3992
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00045: val_loss did not improve from 1.61491
#
# Epoch 00045: val_loss did not improve from 1.61491
#
# Epoch 00045: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00045: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 46/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.5911 - accuracy: 0.4103 - val_loss: 1.6672 - val_accuracy: 0.3830
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00046: val_loss did not improve from 1.61491
#
# Epoch 00046: val_loss did not improve from 1.61491
#
# Epoch 00046: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00046: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 47/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.6061 - accuracy: 0.4032 - val_loss: 1.6442 - val_accuracy: 0.3938
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00047: val_loss did not improve from 1.61491
#
# Epoch 00047: val_loss did not improve from 1.61491
#
# Epoch 00047: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00047: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 48/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.5970 - accuracy: 0.4085 - val_loss: 1.6182 - val_accuracy: 0.4042
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00048: val_loss did not improve from 1.61491
#
# Epoch 00048: val_loss did not improve from 1.61491
#
# Epoch 00048: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00048: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 49/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.5781 - accuracy: 0.4125 - val_loss: 1.6197 - val_accuracy: 0.4051
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00049: val_loss did not improve from 1.61491
#
# Epoch 00049: val_loss did not improve from 1.61491
#
# Epoch 00049: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00049: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 50/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.5904 - accuracy: 0.4085 - val_loss: 1.5990 - val_accuracy: 0.4050
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00050: val_loss improved from 1.61491 to 1.59902, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00050: val_loss improved from 1.61491 to 1.59902, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00050: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00050: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# Epoch 00050: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_epoch50.h5
#
# ***callbacks end***
#
# Epoch 51/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.5737 - accuracy: 0.4157 - val_loss: 1.5990 - val_accuracy: 0.4130
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00051: val_loss improved from 1.59902 to 1.59901, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model.h5
#
# Epoch 00051: val_loss improved from 1.59902 to 1.59901, saving model to AlexNet_Weights/Qkeras/KERAS_check_best_model_weights.h5
#
# Epoch 00051: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00051: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 52/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.5688 - accuracy: 0.4190 - val_loss: 1.6539 - val_accuracy: 0.3883
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00052: val_loss did not improve from 1.59901
#
# Epoch 00052: val_loss did not improve from 1.59901
#
# Epoch 00052: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
#
# Epoch 00052: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# Epoch 53/5000
# 37/37 [==============================] - 1s 14ms/step - loss: 1.5770 - accuracy: 0.4151 - val_loss: 1.6533 - val_accuracy: 0.3942
#
# ***callbacks***
# saving losses to AlexNet_Weights/Qkeras/losses.log
#
# Epoch 00053: val_loss did not improve from 1.59901
#
# Epoch 00053: val_loss did not improve from 1.59901
#
# Epoch 00053: saving model to AlexNet_Weights/Qkeras/KERAS_check_model_last.h5
