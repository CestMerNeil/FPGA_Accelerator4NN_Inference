# %% [markdown]
# # Hyperparamètre

# %%
train_keras = True
train_qkeras =True
model_name = 'AlexNet_Weights/AlexNet_Cifar10_Keras.h5'
qmodel_name_8 = 'AlexNet_Weights/AlexNet_Cifar10_QKeras_8.h5'
qmodel_name_16 = 'AlexNet_Weights/AlexNet_Cifar10_QKeras_16.h5'
epochs = 200
batch_size = 512
lr = 0.001
log_dir_keras = 'AlexNet_Cifar10_LOG/Keras'
log_dir_qkeras_8 = 'AlexNet_Cifar10_LOG/QKeras_8'
log_dir_qkeras_16 = 'AlexNet_Cifar10_LOG/QKeras_16'

# %% [markdown]
# # Dataset Part

# %%
import tensorflow as tf
import keras
import time
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import cifar10
# Out:
# 2023-07-07 04:06:44.161777: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

cifar10_classes=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %% [markdown]
# # Keras Part

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D, Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.optimizers import Adam
model = Sequential()

model.add(
    Input(
        shape=(32, 32, 3)
    )
)

# Conv 1
model.add(
    Conv2D(
    5,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='valid',
    name='conv1'
    )
)
model.add(
    Activation(activation='relu', name='relu1')
)
model.add(
    MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='valid', name='pool1')
)

# Conv 2
model.add(
    Conv2D(
    13,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='valid',
    name='conv2'
    )
)
model.add(
    Activation(activation='relu', name='relu2')
)
model.add(
    MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='valid', name='pool2')
)

# Conv 3
model.add(
    Conv2D(
    20,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding='same',
    name='conv3'
    )
)
model.add(
    Activation(activation='relu', name='relu3')
)

# Conv 4
model.add(
    Conv2D(
    20,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding='same',
    name='conv4'
    )
)
model.add(
    Activation(activation='relu', name='relu4')
)

# Conv 5
model.add(
    Conv2D(
    13,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding='same',
    name='conv5'
    )
)
model.add(
    Activation(activation='relu', name='relu5')
)
model.add(
    MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='valid', name='pool5')
)

# Flatten
model.add(Flatten())

# FC 1
model.add(
    Dense(
        214,
        name='fc1'
    )
)
model.add(
    Activation(activation='relu', name='relu6')
)

# FC 2
model.add(
    Dense(
        16,
        name='fc2'
    )
)
model.add(
    Activation(activation='relu', name='relu7')
)

# FC 3
model.add(
    Dense(
        10,
        name='output'
    )
)

model.add(Activation(activation='softmax', name='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 28, 28, 5)         380
#
#  relu1 (Activation)          (None, 28, 28, 5)         0
#
#  pool1 (MaxPooling2D)        (None, 13, 13, 5)         0
#
#  conv2 (Conv2D)              (None, 9, 9, 13)          1638
#
#  relu2 (Activation)          (None, 9, 9, 13)          0
#
#  pool2 (MaxPooling2D)        (None, 4, 4, 13)          0
#
#  conv3 (Conv2D)              (None, 4, 4, 20)          2360
#
#  relu3 (Activation)          (None, 4, 4, 20)          0
#
#  conv4 (Conv2D)              (None, 4, 4, 20)          3620
#
#  relu4 (Activation)          (None, 4, 4, 20)          0
#
#  conv5 (Conv2D)              (None, 4, 4, 13)          2353
#
#  relu5 (Activation)          (None, 4, 4, 13)          0
#
#  pool5 (MaxPooling2D)        (None, 1, 1, 13)          0
#
#  flatten_1 (Flatten)         (None, 13)                0
#
#  fc1 (Dense)                 (None, 214)               2996
#
#  relu6 (Activation)          (None, 214)               0
#
#  fc2 (Dense)                 (None, 16)                3440
#
#  relu7 (Activation)          (None, 16)                0
#
#  output (Dense)              (None, 10)                170
#
#  softmax (Activation)        (None, 10)                0
#
# =================================================================
# Total params: 16,957
# Trainable params: 16,957
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
adam = Adam(learning_rate=0.001)
model.compile(
    optimizer=adam,
    loss=['categorical_crossentropy'], 
    metrics=['accuracy']
)
model.fit(
    x_train,
    y_train,
    batch_size=4096,
    epochs=100,
    validation_data=(x_test, y_test),
    shuffle=True,
)
model.save('AlexNet_Weights/AlexNet_Normal_Model.h5')
# Out:
# Epoch 1/100
# 13/13 [==============================] - 5s 289ms/step - loss: 2.2886 - accuracy: 0.0901 - val_loss: 2.2512 - val_accuracy: 0.1101
# Epoch 2/100
# 13/13 [==============================] - 3s 266ms/step - loss: 2.2268 - accuracy: 0.1319 - val_loss: 2.1990 - val_accuracy: 0.1667
# Epoch 3/100
# 13/13 [==============================] - 4s 271ms/step - loss: 2.1868 - accuracy: 0.1757 - val_loss: 2.1591 - val_accuracy: 0.1898
# Epoch 4/100
# 13/13 [==============================] - 4s 271ms/step - loss: 2.1479 - accuracy: 0.1877 - val_loss: 2.1236 - val_accuracy: 0.2015
# Epoch 5/100
# 13/13 [==============================] - 3s 268ms/step - loss: 2.1111 - accuracy: 0.2005 - val_loss: 2.0792 - val_accuracy: 0.2189
# Epoch 6/100
# 13/13 [==============================] - 4s 270ms/step - loss: 2.0672 - accuracy: 0.2180 - val_loss: 2.0437 - val_accuracy: 0.2276
# Epoch 7/100
# 13/13 [==============================] - 4s 272ms/step - loss: 2.0205 - accuracy: 0.2342 - val_loss: 1.9871 - val_accuracy: 0.2510
# Epoch 8/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.9672 - accuracy: 0.2527 - val_loss: 1.9350 - val_accuracy: 0.2658
# Epoch 9/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.9286 - accuracy: 0.2687 - val_loss: 1.8940 - val_accuracy: 0.2846
# Epoch 10/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.8847 - accuracy: 0.2800 - val_loss: 1.8886 - val_accuracy: 0.2874
# Epoch 11/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.8584 - accuracy: 0.2930 - val_loss: 1.8430 - val_accuracy: 0.3085
# Epoch 12/100
# 13/13 [==============================] - 4s 272ms/step - loss: 1.8236 - accuracy: 0.3114 - val_loss: 1.8369 - val_accuracy: 0.3258
# Epoch 13/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.7996 - accuracy: 0.3304 - val_loss: 1.7783 - val_accuracy: 0.3397
# Epoch 14/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.7722 - accuracy: 0.3378 - val_loss: 1.7578 - val_accuracy: 0.3478
# Epoch 15/100
# 13/13 [==============================] - 4s 272ms/step - loss: 1.7665 - accuracy: 0.3421 - val_loss: 1.7409 - val_accuracy: 0.3568
# Epoch 16/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.7531 - accuracy: 0.3501 - val_loss: 1.7339 - val_accuracy: 0.3563
# Epoch 17/100
# 13/13 [==============================] - 3s 269ms/step - loss: 1.7342 - accuracy: 0.3578 - val_loss: 1.7193 - val_accuracy: 0.3542
# Epoch 18/100
# 13/13 [==============================] - 4s 272ms/step - loss: 1.7254 - accuracy: 0.3622 - val_loss: 1.7047 - val_accuracy: 0.3708
# Epoch 19/100
# 13/13 [==============================] - 3s 269ms/step - loss: 1.7021 - accuracy: 0.3731 - val_loss: 1.6899 - val_accuracy: 0.3757
# Epoch 20/100
# 13/13 [==============================] - 3s 267ms/step - loss: 1.6908 - accuracy: 0.3755 - val_loss: 1.6835 - val_accuracy: 0.3739
# Epoch 21/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.6808 - accuracy: 0.3787 - val_loss: 1.6942 - val_accuracy: 0.3775
# Epoch 22/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.6777 - accuracy: 0.3838 - val_loss: 1.6865 - val_accuracy: 0.3791
# Epoch 23/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.6693 - accuracy: 0.3823 - val_loss: 1.6715 - val_accuracy: 0.3819
# Epoch 24/100
# 13/13 [==============================] - 3s 269ms/step - loss: 1.6621 - accuracy: 0.3856 - val_loss: 1.6527 - val_accuracy: 0.3876
# Epoch 25/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.6498 - accuracy: 0.3924 - val_loss: 1.6453 - val_accuracy: 0.3906
# Epoch 26/100
# 13/13 [==============================] - 4s 267ms/step - loss: 1.6442 - accuracy: 0.3947 - val_loss: 1.6350 - val_accuracy: 0.3976
# Epoch 27/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.6391 - accuracy: 0.3952 - val_loss: 1.6374 - val_accuracy: 0.3954
# Epoch 28/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.6333 - accuracy: 0.3985 - val_loss: 1.6168 - val_accuracy: 0.4047
# Epoch 29/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.6258 - accuracy: 0.4008 - val_loss: 1.6319 - val_accuracy: 0.3979
# Epoch 30/100
# 13/13 [==============================] - 4s 272ms/step - loss: 1.6251 - accuracy: 0.4029 - val_loss: 1.6188 - val_accuracy: 0.4025
# Epoch 31/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.6110 - accuracy: 0.4067 - val_loss: 1.5975 - val_accuracy: 0.4118
# Epoch 32/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.5993 - accuracy: 0.4121 - val_loss: 1.5982 - val_accuracy: 0.4119
# Epoch 33/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.5923 - accuracy: 0.4161 - val_loss: 1.6046 - val_accuracy: 0.4102
# Epoch 34/100
# 13/13 [==============================] - 3s 267ms/step - loss: 1.5972 - accuracy: 0.4132 - val_loss: 1.6199 - val_accuracy: 0.4093
# Epoch 35/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.5937 - accuracy: 0.4162 - val_loss: 1.5837 - val_accuracy: 0.4179
# Epoch 36/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.5831 - accuracy: 0.4205 - val_loss: 1.5890 - val_accuracy: 0.4131
# Epoch 37/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.5791 - accuracy: 0.4220 - val_loss: 1.5720 - val_accuracy: 0.4202
# Epoch 38/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.5713 - accuracy: 0.4252 - val_loss: 1.5842 - val_accuracy: 0.4107
# Epoch 39/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.5657 - accuracy: 0.4263 - val_loss: 1.5567 - val_accuracy: 0.4252
# Epoch 40/100
# 13/13 [==============================] - 3s 267ms/step - loss: 1.5563 - accuracy: 0.4289 - val_loss: 1.5563 - val_accuracy: 0.4280
# Epoch 41/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.5517 - accuracy: 0.4322 - val_loss: 1.5642 - val_accuracy: 0.4265
# Epoch 42/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.5530 - accuracy: 0.4336 - val_loss: 1.5484 - val_accuracy: 0.4293
# Epoch 43/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.5476 - accuracy: 0.4335 - val_loss: 1.5494 - val_accuracy: 0.4275
# Epoch 44/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.5364 - accuracy: 0.4363 - val_loss: 1.5491 - val_accuracy: 0.4262
# Epoch 45/100
# 13/13 [==============================] - 4s 272ms/step - loss: 1.5387 - accuracy: 0.4380 - val_loss: 1.5423 - val_accuracy: 0.4338
# Epoch 46/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.5430 - accuracy: 0.4364 - val_loss: 1.5281 - val_accuracy: 0.4385
# Epoch 47/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.5277 - accuracy: 0.4428 - val_loss: 1.5370 - val_accuracy: 0.4312
# Epoch 48/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.5296 - accuracy: 0.4416 - val_loss: 1.5258 - val_accuracy: 0.4420
# Epoch 49/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.5163 - accuracy: 0.4466 - val_loss: 1.5243 - val_accuracy: 0.4365
# Epoch 50/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.5139 - accuracy: 0.4468 - val_loss: 1.5237 - val_accuracy: 0.4452
# Epoch 51/100
# 13/13 [==============================] - 3s 267ms/step - loss: 1.5140 - accuracy: 0.4474 - val_loss: 1.5114 - val_accuracy: 0.4467
# Epoch 52/100
# 13/13 [==============================] - 3s 267ms/step - loss: 1.5079 - accuracy: 0.4506 - val_loss: 1.5106 - val_accuracy: 0.4489
# Epoch 53/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.5070 - accuracy: 0.4488 - val_loss: 1.5084 - val_accuracy: 0.4438
# Epoch 54/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.4982 - accuracy: 0.4532 - val_loss: 1.5074 - val_accuracy: 0.4497
# Epoch 55/100
# 13/13 [==============================] - 3s 269ms/step - loss: 1.4967 - accuracy: 0.4566 - val_loss: 1.4967 - val_accuracy: 0.4490
# Epoch 56/100
# 13/13 [==============================] - 3s 269ms/step - loss: 1.4904 - accuracy: 0.4566 - val_loss: 1.5217 - val_accuracy: 0.4397
# Epoch 57/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.5029 - accuracy: 0.4530 - val_loss: 1.5158 - val_accuracy: 0.4449
# Epoch 58/100
# 13/13 [==============================] - 4s 267ms/step - loss: 1.4964 - accuracy: 0.4555 - val_loss: 1.5608 - val_accuracy: 0.4259
# Epoch 59/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.4939 - accuracy: 0.4557 - val_loss: 1.4960 - val_accuracy: 0.4519
# Epoch 60/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.4791 - accuracy: 0.4622 - val_loss: 1.4857 - val_accuracy: 0.4554
# Epoch 61/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.4747 - accuracy: 0.4642 - val_loss: 1.4930 - val_accuracy: 0.4550
# Epoch 62/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.4649 - accuracy: 0.4679 - val_loss: 1.4792 - val_accuracy: 0.4573
# Epoch 63/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.4597 - accuracy: 0.4701 - val_loss: 1.4734 - val_accuracy: 0.4614
# Epoch 64/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.4588 - accuracy: 0.4682 - val_loss: 1.4872 - val_accuracy: 0.4583
# Epoch 65/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.4606 - accuracy: 0.4683 - val_loss: 1.4696 - val_accuracy: 0.4646
# Epoch 66/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.4550 - accuracy: 0.4699 - val_loss: 1.4632 - val_accuracy: 0.4670
# Epoch 67/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.4478 - accuracy: 0.4726 - val_loss: 1.4728 - val_accuracy: 0.4632
# Epoch 68/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.4516 - accuracy: 0.4724 - val_loss: 1.4686 - val_accuracy: 0.4676
# Epoch 69/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.4417 - accuracy: 0.4750 - val_loss: 1.4515 - val_accuracy: 0.4731
# Epoch 70/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.4390 - accuracy: 0.4769 - val_loss: 1.4809 - val_accuracy: 0.4575
# Epoch 71/100
# 13/13 [==============================] - 4s 272ms/step - loss: 1.4504 - accuracy: 0.4736 - val_loss: 1.4529 - val_accuracy: 0.4721
# Epoch 72/100
# 13/13 [==============================] - 3s 267ms/step - loss: 1.4427 - accuracy: 0.4781 - val_loss: 1.5390 - val_accuracy: 0.4424
# Epoch 73/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.4547 - accuracy: 0.4724 - val_loss: 1.4540 - val_accuracy: 0.4741
# Epoch 74/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.4309 - accuracy: 0.4829 - val_loss: 1.5006 - val_accuracy: 0.4550
# Epoch 75/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.4442 - accuracy: 0.4777 - val_loss: 1.4870 - val_accuracy: 0.4651
# Epoch 76/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.4372 - accuracy: 0.4777 - val_loss: 1.4447 - val_accuracy: 0.4777
# Epoch 77/100
# 13/13 [==============================] - 4s 271ms/step - loss: 1.4300 - accuracy: 0.4828 - val_loss: 1.4330 - val_accuracy: 0.4790
# Epoch 78/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.4198 - accuracy: 0.4873 - val_loss: 1.4359 - val_accuracy: 0.4776
# Epoch 79/100
# 13/13 [==============================] - 3s 269ms/step - loss: 1.4111 - accuracy: 0.4877 - val_loss: 1.4335 - val_accuracy: 0.4789
# Epoch 80/100
# 13/13 [==============================] - 3s 269ms/step - loss: 1.4107 - accuracy: 0.4899 - val_loss: 1.4237 - val_accuracy: 0.4849
# Epoch 81/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.4099 - accuracy: 0.4894 - val_loss: 1.4320 - val_accuracy: 0.4805
# Epoch 82/100
# 13/13 [==============================] - 4s 269ms/step - loss: 1.4063 - accuracy: 0.4904 - val_loss: 1.4227 - val_accuracy: 0.4827
# Epoch 83/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.4018 - accuracy: 0.4937 - val_loss: 1.4210 - val_accuracy: 0.4868
# Epoch 84/100
# 13/13 [==============================] - 3s 267ms/step - loss: 1.4011 - accuracy: 0.4933 - val_loss: 1.4191 - val_accuracy: 0.4834
# Epoch 85/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.3962 - accuracy: 0.4953 - val_loss: 1.4190 - val_accuracy: 0.4847
# Epoch 86/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.3934 - accuracy: 0.4959 - val_loss: 1.4083 - val_accuracy: 0.4903
# Epoch 87/100
# 13/13 [==============================] - 3s 267ms/step - loss: 1.3937 - accuracy: 0.4966 - val_loss: 1.4131 - val_accuracy: 0.4879
# Epoch 88/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.3898 - accuracy: 0.4960 - val_loss: 1.4209 - val_accuracy: 0.4832
# Epoch 89/100
# 13/13 [==============================] - 3s 264ms/step - loss: 1.3877 - accuracy: 0.4983 - val_loss: 1.4005 - val_accuracy: 0.4944
# Epoch 90/100
# 13/13 [==============================] - 4s 267ms/step - loss: 1.3823 - accuracy: 0.5009 - val_loss: 1.4189 - val_accuracy: 0.4843
# Epoch 91/100
# 13/13 [==============================] - 3s 269ms/step - loss: 1.3942 - accuracy: 0.4971 - val_loss: 1.4040 - val_accuracy: 0.4889
# Epoch 92/100
# 13/13 [==============================] - 3s 267ms/step - loss: 1.3786 - accuracy: 0.5039 - val_loss: 1.4065 - val_accuracy: 0.4915
# Epoch 93/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.3773 - accuracy: 0.5029 - val_loss: 1.4007 - val_accuracy: 0.4948
# Epoch 94/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.3873 - accuracy: 0.5002 - val_loss: 1.4132 - val_accuracy: 0.4890
# Epoch 95/100
# 13/13 [==============================] - 3s 266ms/step - loss: 1.3783 - accuracy: 0.5033 - val_loss: 1.3967 - val_accuracy: 0.4958
# Epoch 96/100
# 13/13 [==============================] - 3s 269ms/step - loss: 1.3721 - accuracy: 0.5059 - val_loss: 1.4048 - val_accuracy: 0.4884
# Epoch 97/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.3791 - accuracy: 0.5013 - val_loss: 1.4057 - val_accuracy: 0.4943
# Epoch 98/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.3696 - accuracy: 0.5074 - val_loss: 1.3885 - val_accuracy: 0.5007
# Epoch 99/100
# 13/13 [==============================] - 4s 270ms/step - loss: 1.3625 - accuracy: 0.5084 - val_loss: 1.3884 - val_accuracy: 0.5002
# Epoch 100/100
# 13/13 [==============================] - 3s 268ms/step - loss: 1.3590 - accuracy: 0.5115 - val_loss: 1.3866 - val_accuracy: 0.5019

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.3866 - accuracy: 0.5019
# Test Loss: 1.386614203453064
# Test Accuracy: 0.5019000172615051
